# %% [markdown]
# ## Convolutional Neural Network

# %% [markdown]
# In this notebook you will learn to distinguish dogs from cats!
#
# Data:
# https://drive.google.com/drive/folders/1nzVk4GOvKR6P87uPszUkKMPtaXV_wrZf?usp=sharing
#
# Fill all the necessary gaps in cells below and fit neural networks for solving the binary classification task.
#
# ## Task 1:
#
# 1. Build and fit CNN with 3 convolutional layers for binary classification
# 2. Evaluate accuracy on test data
# 3. Plot the graphs for Loss(number_of_epochs) and Accuracy(number_of_epochs)
#
# First, let's load all the necessary functions:

# %%
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D
from keras.applications import VGG16, InceptionV3
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# The images collected for training and testing the deep learning model must be prepared: split the entire set into a training, validation and test sample, observing the balancing of classes (with binary classification they should be approximately equal in all three samples).
#
# This has _already_ been done: in the Cats_and_Dogs directory there are three subdirectories: train, test and val - training, test and validation samples, respectively.

# %%
# Initialize the folders with train, test and validation datasets (in "/My Drive/..." or from your local repository where you have downloaded data):

import os
train = os.path.join('data', 'сats_and_dogs', 'train')
val =   os.path.join('data', 'сats_and_dogs', 'val')
test =  os.path.join('data', 'сats_and_dogs', 'test')

# The shape of the RGB image
img_width, img_height, channels = 150, 150, 3 # you can try different sizes

# input shape
input_shape = (img_width, img_height, channels)
# position matters!
# Number_of_channels can be at the first or the last position
# in our case - "channels last"

# minibatch size
batch_size = 64
# train set size
nb_train_samples = 20000
# validation set size 
nb_validation_samples = 2480
# test set size
nb_test_samples = 2500

# %% [markdown]
# ## Prepare the data.
#
# You don’t have to manually change the shapes of 25000 images and convert them into the necessary format for keras (img_width, img_height, 3).
#
# We will use the built-in image preprocessing function _ImageGenerator()_.
#
# It performs scaling, resizes selected images and prepares batches (mini-samples) to train the model.

# %%
datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = datagen.flow_from_directory(
    train,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=True
)

val_generator = datagen.flow_from_directory(
    val,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)

test_generator = datagen.flow_from_directory(
    test,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False
)
# Out:
# Found 20000 images belonging to 2 classes.
# Found 2490 images belonging to 2 classes.
# Found 2500 images belonging to 2 classes.

# %% [markdown]
# Set the network architecture by sequentially adding layers to it:
# 1. A convolutional layer with 16 neurons, filter size 3x3. Activation function - 'relu'
# 2. MaxPooling layer with filter size 2x2.
# 3. A convolutional layer with 32 neurons, filter size 3x3. Activation function - 'relu'
# 4. MaxPooling layer with filter size 2x2.
# 5. A convolutional layer with 64 neurons, filter size 3x3. Activation function - 'relu'
# 6. MaxPooling layer with filter size 2x2.
# 7. Operation model.add (Flatten ()), which makes a one-dimensional vector of the resulting feature maps.
# 8. A fully connected layer with 64 neurons. Activation function - 'relu'
# 9. Use model.add (Dropout (0.5)) which excludes the edge from the current layer in the computational graph with a 50% probability to avoid overfitting.
# 10. A fully connected layer with 1 neuron. Activation function - 'sigmoid', because binary classification model.
#
# Add to the model all the missing layers, by analogy with the already specified.
# Keras documentation: https://keras.io/layers/about-keras-layers/

# %%
model = Sequential()

# 1: +Convolutional +Relu
model.add(Conv2D(16, (3, 3), input_shape=(150, 150, 3)))
model.add(Activation('relu'))

# 2: +Pooling
model.add(MaxPooling2D(pool_size=(2, 2)))

# 3: +Convolutional +Relu
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))

# 4:  +Pooling
model.add(MaxPooling2D(pool_size=(2, 2)))

# 5:  +Convolutional +Relu
model.add(Conv2D(64, (3, 3), input_shape=(150, 150, 3)))
model.add(Activation('relu'))

# 6:  +Pooling
model.add(MaxPooling2D(pool_size=(2, 2)))

# 7:  +Flattening
model.add(Flatten())

# 8:  +Dense +Relu
model.add(Dense(64))
model.add(Activation('relu'))

# 9:  +Dropout
model.add(Dropout(0.5))

# 10: +Dense +Sigmoid
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)

# %%
# use the generator to train the model (analogue of the fit method)
# 1 epoch of training on a CPU will take 4-6 minutes. The GPU is an ~order of magnitude faster.
# THE FIRST EPOCH USUALLY TAKES MUCH LARGER TIME AS KERAS SHOULD BUILD THE COMPUTATIONAL GRAPH

history = model.fit(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=10, # try different number of epochs: 10, 15, 20; check the loss and accuracy;
    validation_data=val_generator,
    validation_steps=nb_validation_samples // batch_size
)
# Out:
# Epoch 1/10
# 312/312 [==============================] - 17s 54ms/step - loss: 0.6296 - accuracy: 0.6346 - val_loss: 0.5523 - val_accuracy: 0.7315
# Epoch 2/10
# 312/312 [==============================] - 16s 52ms/step - loss: 0.5462 - accuracy: 0.7297 - val_loss: 0.5142 - val_accuracy: 0.7504
# Epoch 3/10
# 312/312 [==============================] - 16s 53ms/step - loss: 0.4845 - accuracy: 0.7699 - val_loss: 0.4616 - val_accuracy: 0.7850
# Epoch 4/10
# 312/312 [==============================] - 17s 53ms/step - loss: 0.4416 - accuracy: 0.8020 - val_loss: 0.4413 - val_accuracy: 0.8076
# Epoch 5/10
# 312/312 [==============================] - 17s 54ms/step - loss: 0.3987 - accuracy: 0.8253 - val_loss: 0.4320 - val_accuracy: 0.8129
# Epoch 6/10
# 312/312 [==============================] - 16s 52ms/step - loss: 0.3653 - accuracy: 0.8410 - val_loss: 0.3935 - val_accuracy: 0.8261
# Epoch 7/10
# 312/312 [==============================] - 16s 51ms/step - loss: 0.3293 - accuracy: 0.8592 - val_loss: 0.3934 - val_accuracy: 0.8265
# Epoch 8/10
# 312/312 [==============================] - 16s 51ms/step - loss: 0.2992 - accuracy: 0.8713 - val_loss: 0.4038 - val_accuracy: 0.8248
# Epoch 9/10
# 312/312 [==============================] - 16s 50ms/step - loss: 0.2593 - accuracy: 0.8912 - val_loss: 0.3931 - val_accuracy: 0.8372
# Epoch 10/10
# 312/312 [==============================] - 16s 50ms/step - loss: 0.2329 - accuracy: 0.8995 - val_loss: 0.4080 - val_accuracy: 0.8372

# %%
# NOTE: if the accuracy on test data after 15 epochs is less than 80% smth goes wrong

scores = model.evaluate_generator(test_generator, nb_test_samples // batch_size)
print("Accuracy on test data: %.2f%%" % (scores[1]*100))
# Out:
# C:\Users\prazd\AppData\Local\Temp\ipykernel_3396\2304885300.py:3: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   scores = model.evaluate_generator(test_generator, nb_test_samples // batch_size)
# Accuracy on test data: 83.93%

# %% [markdown]
# Plot the graphs:
#
# - Loss(Number of epochs)
#
# - Accuracy(Number of epochs)

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt
img = mpimg.imread('/content/drive/My Drive/Deeper.jpeg')
plt.figure(figsize = (10,20))
plt.imshow(img)
plt.show()

# %% [markdown]
# Let's try to improve the quality of recognition, using the method of transfer lerning.
#
# We will use weights of deep neural networks already trained on large dataset such as  ImageNet, and provide fine tuning of several additional dense layers on new data relevant to the current classification task. The more new images will differ from those on which the network has been trained, the more layers will need to be “retrained” in order to get good classification accuracy. The intuition here is that the model has already learned how to highlight the necessary features on the images in the large dataset, it only needs to be “tweaked” for a specific task.
#
# ## Task 2
#
# 1. Build and fit Transfer Learning model using pre-trained VGG16-model weights from keras application.
# 2. Do the same with **another avaliable pre-trained deep learning model** from keras application https://keras.io/api/applications/.
# 2. Evaluate accuracy on test data for p.1 and p.2
# 3. Plot the graphs for Loss(number_of_epochs) and Accuracy(number_of_epochs)
# 4. Check the performance of your model with the custom image of cat or dog (so the model will tell which class this image belongs to). Develop the function for the inference of the best algorithm.

# %%
# First, download the weights of the VGG16 network trained on the ImageNet dataset:

vgg16_net = VGG16(
    weights='imagenet', 
    include_top=False,                    # we take only the "convolution" part, the last layers we add ourselves
    input_shape=(150, 150, 3)
)

vgg16_net.trainable = False               # clearly prescribe that we do NOT overload the network.
                                          # Weights VGG16 in the process of learning will remain unchanged!

vgg16_net.summary()                       # pay attention to the number of trained and untrained parameters
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 150, 150, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 150, 150, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 150, 150, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 75, 75, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 75, 75, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 75, 75, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 37, 37, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 37, 37, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 37, 37, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 18, 18, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 18, 18, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  block5_conv1 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv2 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_conv3 (Conv2D)       (None, 9, 9, 512)         2359808
#
#  block5_pool (MaxPooling2D)  (None, 4, 4, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# We construct our model of "transfer learning" by adding two fully connected layers to VGG16

# %%
# add layers to VGG16:

model = Sequential()
model.add(vgg16_net)
model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dense_2 (Dense)             (None, 256)               2097408
#
#  activation_5 (Activation)   (None, 256)               0
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 1)                 257
#
#  activation_6 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 16,812,353
# Trainable params: 2,097,665
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer=Adam(learning_rate=1e-5), 
    metrics=['accuracy']
)

# %% [markdown]
# E.g., it was like:

# %%
img = mpimg.imread('/content/drive/My Drive/VGG16.png')
plt.figure(figsize = (10,20))
plt.imshow(img)
plt.show()

# %% [markdown]
# and it becomes:

# %%
img = mpimg.imread('/content/drive/My Drive/VGG162.png')
plt.figure(figsize = (10,20))
plt.imshow(img)
plt.show()

# %%
# We also use the generator to train the model (similar to the fit method)
# Without using a GPU, learning 1 epoch of such a network will take about an hour. Plan your time =)
# If you have access to a GPU, you can try 10-12 epochs - the quality should increase even more.

history = model.fit(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=10,
    validation_data=val_generator,
    validation_steps=nb_validation_samples // batch_size
)
# Out:
# Epoch 1/10
# 312/312 [==============================] - 47s 150ms/step - loss: 0.4938 - accuracy: 0.7529 - val_loss: 0.3476 - val_accuracy: 0.8528
# Epoch 2/10
# 312/312 [==============================] - 47s 149ms/step - loss: 0.3386 - accuracy: 0.8537 - val_loss: 0.2910 - val_accuracy: 0.8812
# Epoch 3/10
# 312/312 [==============================] - 47s 149ms/step - loss: 0.2946 - accuracy: 0.8746 - val_loss: 0.2671 - val_accuracy: 0.8898
# Epoch 4/10
# 312/312 [==============================] - 47s 150ms/step - loss: 0.2721 - accuracy: 0.8864 - val_loss: 0.2532 - val_accuracy: 0.9009
# Epoch 5/10
# 312/312 [==============================] - 47s 151ms/step - loss: 0.2560 - accuracy: 0.8945 - val_loss: 0.2443 - val_accuracy: 0.9062
# Epoch 6/10
# 312/312 [==============================] - 47s 150ms/step - loss: 0.2442 - accuracy: 0.8975 - val_loss: 0.2370 - val_accuracy: 0.9046
# Epoch 7/10
# 312/312 [==============================] - 47s 151ms/step - loss: 0.2376 - accuracy: 0.9034 - val_loss: 0.2320 - val_accuracy: 0.9095
# Epoch 8/10
# 312/312 [==============================] - 47s 150ms/step - loss: 0.2270 - accuracy: 0.9064 - val_loss: 0.2268 - val_accuracy: 0.9120
# Epoch 9/10
# 312/312 [==============================] - 47s 151ms/step - loss: 0.2198 - accuracy: 0.9112 - val_loss: 0.2261 - val_accuracy: 0.9149
# Epoch 10/10
# 312/312 [==============================] - 47s 150ms/step - loss: 0.2146 - accuracy: 0.9137 - val_loss: 0.2217 - val_accuracy: 0.9182

# %%
scores = model.evaluate_generator(test_generator, nb_test_samples // batch_size)
print("Accuracy on test data: %.2f%%" % (scores[1]*100))
# Out:
# C:\Users\prazd\AppData\Local\Temp\ipykernel_3396\477001200.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   scores = model.evaluate_generator(test_generator, nb_test_samples // batch_size)
# Accuracy on test data: 89.90%

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss with VGG16')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy with VGG16')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ### Try InceptionV3

# %%
inceptionV3_net = InceptionV3(
    weights='imagenet', 
    include_top=False,
    input_shape=(150, 150, 3)
)
inceptionV3_net.trainable = False

inceptionV3_net.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 150, 150, 3  0           []
#                                 )]
#
#  conv2d_97 (Conv2D)             (None, 74, 74, 32)   864         ['input_3[0][0]']
#
#  batch_normalization_94 (BatchN  (None, 74, 74, 32)  96          ['conv2d_97[0][0]']
#  ormalization)
#
#  activation_101 (Activation)    (None, 74, 74, 32)   0           ['batch_normalization_94[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 72, 72, 32)   9216        ['activation_101[0][0]']
#
#  batch_normalization_95 (BatchN  (None, 72, 72, 32)  96          ['conv2d_98[0][0]']
#  ormalization)
#
#  activation_102 (Activation)    (None, 72, 72, 32)   0           ['batch_normalization_95[0][0]']
#
#  conv2d_99 (Conv2D)             (None, 72, 72, 64)   18432       ['activation_102[0][0]']
#
#  batch_normalization_96 (BatchN  (None, 72, 72, 64)  192         ['conv2d_99[0][0]']
#  ormalization)
#
#  activation_103 (Activation)    (None, 72, 72, 64)   0           ['batch_normalization_96[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 35, 35, 64)  0           ['activation_103[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 35, 35, 80)   5120        ['max_pooling2d_7[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 35, 35, 80)  240         ['conv2d_100[0][0]']
#  ormalization)
#
#  activation_104 (Activation)    (None, 35, 35, 80)   0           ['batch_normalization_97[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 33, 33, 192)  138240      ['activation_104[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 33, 33, 192)  576        ['conv2d_101[0][0]']
#  ormalization)
#
#  activation_105 (Activation)    (None, 33, 33, 192)  0           ['batch_normalization_98[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 16, 16, 192)  0          ['activation_105[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 16, 16, 64)   12288       ['max_pooling2d_8[0][0]']
#
#  batch_normalization_102 (Batch  (None, 16, 16, 64)  192         ['conv2d_105[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_102[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 16, 16, 48)   9216        ['max_pooling2d_8[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 16, 16, 96)   55296       ['activation_109[0][0]']
#
#  batch_normalization_100 (Batch  (None, 16, 16, 48)  144         ['conv2d_103[0][0]']
#  Normalization)
#
#  batch_normalization_103 (Batch  (None, 16, 16, 96)  288         ['conv2d_106[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_100[0][0]']
#
#  activation_110 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_103[0][0]']
#
#  average_pooling2d_9 (AveragePo  (None, 16, 16, 192)  0          ['max_pooling2d_8[0][0]']
#  oling2D)
#
#  conv2d_102 (Conv2D)            (None, 16, 16, 64)   12288       ['max_pooling2d_8[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 16, 16, 64)   76800       ['activation_107[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 16, 16, 96)   82944       ['activation_110[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 16, 16, 32)   6144        ['average_pooling2d_9[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 16, 16, 64)  192         ['conv2d_102[0][0]']
#  ormalization)
#
#  batch_normalization_101 (Batch  (None, 16, 16, 64)  192         ['conv2d_104[0][0]']
#  Normalization)
#
#  batch_normalization_104 (Batch  (None, 16, 16, 96)  288         ['conv2d_107[0][0]']
#  Normalization)
#
#  batch_normalization_105 (Batch  (None, 16, 16, 32)  96          ['conv2d_108[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_99[0][0]']
#
#  activation_108 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_101[0][0]']
#
#  activation_111 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_104[0][0]']
#
#  activation_112 (Activation)    (None, 16, 16, 32)   0           ['batch_normalization_105[0][0]']
#
#  mixed0 (Concatenate)           (None, 16, 16, 256)  0           ['activation_106[0][0]',
#                                                                   'activation_108[0][0]',
#                                                                   'activation_111[0][0]',
#                                                                   'activation_112[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 16, 16, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_109 (Batch  (None, 16, 16, 64)  192         ['conv2d_112[0][0]']
#  Normalization)
#
#  activation_116 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_109[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 16, 16, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 16, 16, 96)   55296       ['activation_116[0][0]']
#
#  batch_normalization_107 (Batch  (None, 16, 16, 48)  144         ['conv2d_110[0][0]']
#  Normalization)
#
#  batch_normalization_110 (Batch  (None, 16, 16, 96)  288         ['conv2d_113[0][0]']
#  Normalization)
#
#  activation_114 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_107[0][0]']
#
#  activation_117 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_110[0][0]']
#
#  average_pooling2d_10 (AverageP  (None, 16, 16, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_109 (Conv2D)            (None, 16, 16, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 16, 16, 64)   76800       ['activation_114[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 16, 16, 96)   82944       ['activation_117[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 16, 16, 64)   16384       ['average_pooling2d_10[0][0]']
#
#  batch_normalization_106 (Batch  (None, 16, 16, 64)  192         ['conv2d_109[0][0]']
#  Normalization)
#
#  batch_normalization_108 (Batch  (None, 16, 16, 64)  192         ['conv2d_111[0][0]']
#  Normalization)
#
#  batch_normalization_111 (Batch  (None, 16, 16, 96)  288         ['conv2d_114[0][0]']
#  Normalization)
#
#  batch_normalization_112 (Batch  (None, 16, 16, 64)  192         ['conv2d_115[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_106[0][0]']
#
#  activation_115 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_108[0][0]']
#
#  activation_118 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_111[0][0]']
#
#  activation_119 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_112[0][0]']
#
#  mixed1 (Concatenate)           (None, 16, 16, 288)  0           ['activation_113[0][0]',
#                                                                   'activation_115[0][0]',
#                                                                   'activation_118[0][0]',
#                                                                   'activation_119[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 16, 16, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_116 (Batch  (None, 16, 16, 64)  192         ['conv2d_119[0][0]']
#  Normalization)
#
#  activation_123 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_116[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 16, 16, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 16, 16, 96)   55296       ['activation_123[0][0]']
#
#  batch_normalization_114 (Batch  (None, 16, 16, 48)  144         ['conv2d_117[0][0]']
#  Normalization)
#
#  batch_normalization_117 (Batch  (None, 16, 16, 96)  288         ['conv2d_120[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 16, 16, 48)   0           ['batch_normalization_114[0][0]']
#
#  activation_124 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_117[0][0]']
#
#  average_pooling2d_11 (AverageP  (None, 16, 16, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_116 (Conv2D)            (None, 16, 16, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 16, 16, 64)   76800       ['activation_121[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 16, 16, 96)   82944       ['activation_124[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 16, 16, 64)   18432       ['average_pooling2d_11[0][0]']
#
#  batch_normalization_113 (Batch  (None, 16, 16, 64)  192         ['conv2d_116[0][0]']
#  Normalization)
#
#  batch_normalization_115 (Batch  (None, 16, 16, 64)  192         ['conv2d_118[0][0]']
#  Normalization)
#
#  batch_normalization_118 (Batch  (None, 16, 16, 96)  288         ['conv2d_121[0][0]']
#  Normalization)
#
#  batch_normalization_119 (Batch  (None, 16, 16, 64)  192         ['conv2d_122[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_113[0][0]']
#
#  activation_122 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_115[0][0]']
#
#  activation_125 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_118[0][0]']
#
#  activation_126 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_119[0][0]']
#
#  mixed2 (Concatenate)           (None, 16, 16, 288)  0           ['activation_120[0][0]',
#                                                                   'activation_122[0][0]',
#                                                                   'activation_125[0][0]',
#                                                                   'activation_126[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 16, 16, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_121 (Batch  (None, 16, 16, 64)  192         ['conv2d_124[0][0]']
#  Normalization)
#
#  activation_128 (Activation)    (None, 16, 16, 64)   0           ['batch_normalization_121[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 16, 16, 96)   55296       ['activation_128[0][0]']
#
#  batch_normalization_122 (Batch  (None, 16, 16, 96)  288         ['conv2d_125[0][0]']
#  Normalization)
#
#  activation_129 (Activation)    (None, 16, 16, 96)   0           ['batch_normalization_122[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 7, 7, 384)    995328      ['mixed2[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 7, 7, 96)     82944       ['activation_129[0][0]']
#
#  batch_normalization_120 (Batch  (None, 7, 7, 384)   1152        ['conv2d_123[0][0]']
#  Normalization)
#
#  batch_normalization_123 (Batch  (None, 7, 7, 96)    288         ['conv2d_126[0][0]']
#  Normalization)
#
#  activation_127 (Activation)    (None, 7, 7, 384)    0           ['batch_normalization_120[0][0]']
#
#  activation_130 (Activation)    (None, 7, 7, 96)     0           ['batch_normalization_123[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 7, 7, 288)   0           ['mixed2[0][0]']
#
#  mixed3 (Concatenate)           (None, 7, 7, 768)    0           ['activation_127[0][0]',
#                                                                   'activation_130[0][0]',
#                                                                   'max_pooling2d_9[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 7, 7, 128)    98304       ['mixed3[0][0]']
#
#  batch_normalization_128 (Batch  (None, 7, 7, 128)   384         ['conv2d_131[0][0]']
#  Normalization)
#
#  activation_135 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_128[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 7, 7, 128)    114688      ['activation_135[0][0]']
#
#  batch_normalization_129 (Batch  (None, 7, 7, 128)   384         ['conv2d_132[0][0]']
#  Normalization)
#
#  activation_136 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_129[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 7, 7, 128)    98304       ['mixed3[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 7, 7, 128)    114688      ['activation_136[0][0]']
#
#  batch_normalization_125 (Batch  (None, 7, 7, 128)   384         ['conv2d_128[0][0]']
#  Normalization)
#
#  batch_normalization_130 (Batch  (None, 7, 7, 128)   384         ['conv2d_133[0][0]']
#  Normalization)
#
#  activation_132 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_125[0][0]']
#
#  activation_137 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_130[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 7, 7, 128)    114688      ['activation_132[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 7, 7, 128)    114688      ['activation_137[0][0]']
#
#  batch_normalization_126 (Batch  (None, 7, 7, 128)   384         ['conv2d_129[0][0]']
#  Normalization)
#
#  batch_normalization_131 (Batch  (None, 7, 7, 128)   384         ['conv2d_134[0][0]']
#  Normalization)
#
#  activation_133 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_126[0][0]']
#
#  activation_138 (Activation)    (None, 7, 7, 128)    0           ['batch_normalization_131[0][0]']
#
#  average_pooling2d_12 (AverageP  (None, 7, 7, 768)   0           ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_127 (Conv2D)            (None, 7, 7, 192)    147456      ['mixed3[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 7, 7, 192)    172032      ['activation_133[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 7, 7, 192)    172032      ['activation_138[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 7, 7, 192)    147456      ['average_pooling2d_12[0][0]']
#
#  batch_normalization_124 (Batch  (None, 7, 7, 192)   576         ['conv2d_127[0][0]']
#  Normalization)
#
#  batch_normalization_127 (Batch  (None, 7, 7, 192)   576         ['conv2d_130[0][0]']
#  Normalization)
#
#  batch_normalization_132 (Batch  (None, 7, 7, 192)   576         ['conv2d_135[0][0]']
#  Normalization)
#
#  batch_normalization_133 (Batch  (None, 7, 7, 192)   576         ['conv2d_136[0][0]']
#  Normalization)
#
#  activation_131 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_124[0][0]']
#
#  activation_134 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_127[0][0]']
#
#  activation_139 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_132[0][0]']
#
#  activation_140 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_133[0][0]']
#
#  mixed4 (Concatenate)           (None, 7, 7, 768)    0           ['activation_131[0][0]',
#                                                                   'activation_134[0][0]',
#                                                                   'activation_139[0][0]',
#                                                                   'activation_140[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 7, 7, 160)    122880      ['mixed4[0][0]']
#
#  batch_normalization_138 (Batch  (None, 7, 7, 160)   480         ['conv2d_141[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_138[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_145[0][0]']
#
#  batch_normalization_139 (Batch  (None, 7, 7, 160)   480         ['conv2d_142[0][0]']
#  Normalization)
#
#  activation_146 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_139[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 7, 7, 160)    122880      ['mixed4[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_146[0][0]']
#
#  batch_normalization_135 (Batch  (None, 7, 7, 160)   480         ['conv2d_138[0][0]']
#  Normalization)
#
#  batch_normalization_140 (Batch  (None, 7, 7, 160)   480         ['conv2d_143[0][0]']
#  Normalization)
#
#  activation_142 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_135[0][0]']
#
#  activation_147 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_140[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_142[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_147[0][0]']
#
#  batch_normalization_136 (Batch  (None, 7, 7, 160)   480         ['conv2d_139[0][0]']
#  Normalization)
#
#  batch_normalization_141 (Batch  (None, 7, 7, 160)   480         ['conv2d_144[0][0]']
#  Normalization)
#
#  activation_143 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_136[0][0]']
#
#  activation_148 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_141[0][0]']
#
#  average_pooling2d_13 (AverageP  (None, 7, 7, 768)   0           ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_137 (Conv2D)            (None, 7, 7, 192)    147456      ['mixed4[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 7, 7, 192)    215040      ['activation_143[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 7, 7, 192)    215040      ['activation_148[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 7, 7, 192)    147456      ['average_pooling2d_13[0][0]']
#
#  batch_normalization_134 (Batch  (None, 7, 7, 192)   576         ['conv2d_137[0][0]']
#  Normalization)
#
#  batch_normalization_137 (Batch  (None, 7, 7, 192)   576         ['conv2d_140[0][0]']
#  Normalization)
#
#  batch_normalization_142 (Batch  (None, 7, 7, 192)   576         ['conv2d_145[0][0]']
#  Normalization)
#
#  batch_normalization_143 (Batch  (None, 7, 7, 192)   576         ['conv2d_146[0][0]']
#  Normalization)
#
#  activation_141 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_134[0][0]']
#
#  activation_144 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_137[0][0]']
#
#  activation_149 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_142[0][0]']
#
#  activation_150 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_143[0][0]']
#
#  mixed5 (Concatenate)           (None, 7, 7, 768)    0           ['activation_141[0][0]',
#                                                                   'activation_144[0][0]',
#                                                                   'activation_149[0][0]',
#                                                                   'activation_150[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 7, 7, 160)    122880      ['mixed5[0][0]']
#
#  batch_normalization_148 (Batch  (None, 7, 7, 160)   480         ['conv2d_151[0][0]']
#  Normalization)
#
#  activation_155 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_148[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_155[0][0]']
#
#  batch_normalization_149 (Batch  (None, 7, 7, 160)   480         ['conv2d_152[0][0]']
#  Normalization)
#
#  activation_156 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_149[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 7, 7, 160)    122880      ['mixed5[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_156[0][0]']
#
#  batch_normalization_145 (Batch  (None, 7, 7, 160)   480         ['conv2d_148[0][0]']
#  Normalization)
#
#  batch_normalization_150 (Batch  (None, 7, 7, 160)   480         ['conv2d_153[0][0]']
#  Normalization)
#
#  activation_152 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_145[0][0]']
#
#  activation_157 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_150[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_152[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 7, 7, 160)    179200      ['activation_157[0][0]']
#
#  batch_normalization_146 (Batch  (None, 7, 7, 160)   480         ['conv2d_149[0][0]']
#  Normalization)
#
#  batch_normalization_151 (Batch  (None, 7, 7, 160)   480         ['conv2d_154[0][0]']
#  Normalization)
#
#  activation_153 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_146[0][0]']
#
#  activation_158 (Activation)    (None, 7, 7, 160)    0           ['batch_normalization_151[0][0]']
#
#  average_pooling2d_14 (AverageP  (None, 7, 7, 768)   0           ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_147 (Conv2D)            (None, 7, 7, 192)    147456      ['mixed5[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 7, 7, 192)    215040      ['activation_153[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 7, 7, 192)    215040      ['activation_158[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 7, 7, 192)    147456      ['average_pooling2d_14[0][0]']
#
#  batch_normalization_144 (Batch  (None, 7, 7, 192)   576         ['conv2d_147[0][0]']
#  Normalization)
#
#  batch_normalization_147 (Batch  (None, 7, 7, 192)   576         ['conv2d_150[0][0]']
#  Normalization)
#
#  batch_normalization_152 (Batch  (None, 7, 7, 192)   576         ['conv2d_155[0][0]']
#  Normalization)
#
#  batch_normalization_153 (Batch  (None, 7, 7, 192)   576         ['conv2d_156[0][0]']
#  Normalization)
#
#  activation_151 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_144[0][0]']
#
#  activation_154 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_147[0][0]']
#
#  activation_159 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_152[0][0]']
#
#  activation_160 (Activation)    (None, 7, 7, 192)    0           ['batch_normalization_153[0][0]']
#
#  mixed6 (Concatenate)           (None, 7, 7, 768)    0           ['activation_151[0][0]',
#                                                                   'activation_154[0][0]',
#                                                                   'activation_159[0][0]',
#                                                                   'activation_160[0][0]']
#
# ...
#  mixed8 (Concatenate)           (None, 3, 3, 1280)   0           ['activation_172[0][0]',
#                                                                   'activation_176[0][0]',
#                                                                   'max_pooling2d_10[0][0]']
#
#  conv2d_177 (Conv2D)            (None, 3, 3, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_174 (Batch  (None, 3, 3, 448)   1344        ['conv2d_177[0][0]']
#  Normalization)
#
#  activation_181 (Activation)    (None, 3, 3, 448)    0           ['batch_normalization_174[0][0]']
#
#  conv2d_174 (Conv2D)            (None, 3, 3, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_178 (Conv2D)            (None, 3, 3, 384)    1548288     ['activation_181[0][0]']
#
#  batch_normalization_171 (Batch  (None, 3, 3, 384)   1152        ['conv2d_174[0][0]']
#  Normalization)
#
#  batch_normalization_175 (Batch  (None, 3, 3, 384)   1152        ['conv2d_178[0][0]']
#  Normalization)
#
#  activation_178 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_171[0][0]']
#
#  activation_182 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_175[0][0]']
#
#  conv2d_175 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_178[0][0]']
#
#  conv2d_176 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_178[0][0]']
#
#  conv2d_179 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_182[0][0]']
#
#  conv2d_180 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_182[0][0]']
#
#  average_pooling2d_16 (AverageP  (None, 3, 3, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_173 (Conv2D)            (None, 3, 3, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_172 (Batch  (None, 3, 3, 384)   1152        ['conv2d_175[0][0]']
#  Normalization)
#
#  batch_normalization_173 (Batch  (None, 3, 3, 384)   1152        ['conv2d_176[0][0]']
#  Normalization)
#
#  batch_normalization_176 (Batch  (None, 3, 3, 384)   1152        ['conv2d_179[0][0]']
#  Normalization)
#
#  batch_normalization_177 (Batch  (None, 3, 3, 384)   1152        ['conv2d_180[0][0]']
#  Normalization)
#
#  conv2d_181 (Conv2D)            (None, 3, 3, 192)    245760      ['average_pooling2d_16[0][0]']
#
#  batch_normalization_170 (Batch  (None, 3, 3, 320)   960         ['conv2d_173[0][0]']
#  Normalization)
#
#  activation_179 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_172[0][0]']
#
#  activation_180 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_173[0][0]']
#
#  activation_183 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_176[0][0]']
#
#  activation_184 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_177[0][0]']
#
#  batch_normalization_178 (Batch  (None, 3, 3, 192)   576         ['conv2d_181[0][0]']
#  Normalization)
#
#  activation_177 (Activation)    (None, 3, 3, 320)    0           ['batch_normalization_170[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 3, 3, 768)    0           ['activation_179[0][0]',
#                                                                   'activation_180[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 3, 3, 768)    0           ['activation_183[0][0]',
#                                                                   'activation_184[0][0]']
#
#  activation_185 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_178[0][0]']
#
#  mixed9 (Concatenate)           (None, 3, 3, 2048)   0           ['activation_177[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_2[0][0]',
#                                                                   'activation_185[0][0]']
#
#  conv2d_186 (Conv2D)            (None, 3, 3, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_183 (Batch  (None, 3, 3, 448)   1344        ['conv2d_186[0][0]']
#  Normalization)
#
#  activation_190 (Activation)    (None, 3, 3, 448)    0           ['batch_normalization_183[0][0]']
#
#  conv2d_183 (Conv2D)            (None, 3, 3, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_187 (Conv2D)            (None, 3, 3, 384)    1548288     ['activation_190[0][0]']
#
#  batch_normalization_180 (Batch  (None, 3, 3, 384)   1152        ['conv2d_183[0][0]']
#  Normalization)
#
#  batch_normalization_184 (Batch  (None, 3, 3, 384)   1152        ['conv2d_187[0][0]']
#  Normalization)
#
#  activation_187 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_180[0][0]']
#
#  activation_191 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_184[0][0]']
#
#  conv2d_184 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_187[0][0]']
#
#  conv2d_185 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_187[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_191[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 3, 3, 384)    442368      ['activation_191[0][0]']
#
#  average_pooling2d_17 (AverageP  (None, 3, 3, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_182 (Conv2D)            (None, 3, 3, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_181 (Batch  (None, 3, 3, 384)   1152        ['conv2d_184[0][0]']
#  Normalization)
#
#  batch_normalization_182 (Batch  (None, 3, 3, 384)   1152        ['conv2d_185[0][0]']
#  Normalization)
#
#  batch_normalization_185 (Batch  (None, 3, 3, 384)   1152        ['conv2d_188[0][0]']
#  Normalization)
#
#  batch_normalization_186 (Batch  (None, 3, 3, 384)   1152        ['conv2d_189[0][0]']
#  Normalization)
#
#  conv2d_190 (Conv2D)            (None, 3, 3, 192)    393216      ['average_pooling2d_17[0][0]']
#
#  batch_normalization_179 (Batch  (None, 3, 3, 320)   960         ['conv2d_182[0][0]']
#  Normalization)
#
#  activation_188 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_181[0][0]']
#
#  activation_189 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_182[0][0]']
#
#  activation_192 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_185[0][0]']
#
#  activation_193 (Activation)    (None, 3, 3, 384)    0           ['batch_normalization_186[0][0]']
#
#  batch_normalization_187 (Batch  (None, 3, 3, 192)   576         ['conv2d_190[0][0]']
#  Normalization)
#
#  activation_186 (Activation)    (None, 3, 3, 320)    0           ['batch_normalization_179[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 3, 3, 768)    0           ['activation_188[0][0]',
#                                                                   'activation_189[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 3, 3, 768)    0           ['activation_192[0][0]',
#                                                                   'activation_193[0][0]']
#
#  activation_194 (Activation)    (None, 3, 3, 192)    0           ['batch_normalization_187[0][0]']
#
#  mixed10 (Concatenate)          (None, 3, 3, 2048)   0           ['activation_186[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_3[0][0]',
#                                                                   'activation_194[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %% [markdown]
# We construct our model of "transfer learning" by adding two fully connected layers to VGG16

# %%
# add layers to VGG16:

model = Sequential()
model.add(inceptionV3_net)
model.add(Flatten())
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 3, 3, 2048)        21802784
#
#  flatten_2 (Flatten)         (None, 18432)             0
#
#  dense_4 (Dense)             (None, 128)               2359424
#
#  activation_195 (Activation)  (None, 128)              0
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_5 (Dense)             (None, 1)                 129
#
#  activation_196 (Activation)  (None, 1)                0
#
# =================================================================
# Total params: 24,162,337
# Trainable params: 2,359,553
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
model.compile(
    loss='binary_crossentropy',
    optimizer=Adam(learning_rate=1e-5), 
    metrics=['accuracy']
)

# %%
# We also use the generator to train the model (similar to the fit method)
# Without using a GPU, learning 1 epoch of such a network will take about an hour. Plan your time =)
# If you have access to a GPU, you can try 10-12 epochs - the quality should increase even more.

history = model.fit(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=10,
    validation_data=val_generator,
    validation_steps=nb_validation_samples // batch_size
)
# Out:
# Epoch 1/10
# 312/312 [==============================] - 26s 75ms/step - loss: 0.2172 - accuracy: 0.9142 - val_loss: 0.1076 - val_accuracy: 0.9535
# Epoch 2/10
# 312/312 [==============================] - 36s 114ms/step - loss: 0.1162 - accuracy: 0.9547 - val_loss: 0.0982 - val_accuracy: 0.9601
# Epoch 3/10
# 312/312 [==============================] - 36s 114ms/step - loss: 0.0964 - accuracy: 0.9623 - val_loss: 0.0965 - val_accuracy: 0.9605
# Epoch 4/10
# 312/312 [==============================] - 36s 115ms/step - loss: 0.0853 - accuracy: 0.9667 - val_loss: 0.0924 - val_accuracy: 0.9626
# Epoch 5/10
# 312/312 [==============================] - 35s 113ms/step - loss: 0.0734 - accuracy: 0.9714 - val_loss: 0.0882 - val_accuracy: 0.9663
# Epoch 6/10
# 312/312 [==============================] - 20s 64ms/step - loss: 0.0696 - accuracy: 0.9744 - val_loss: 0.0886 - val_accuracy: 0.9671
# Epoch 7/10
# 312/312 [==============================] - 18s 56ms/step - loss: 0.0600 - accuracy: 0.9767 - val_loss: 0.0905 - val_accuracy: 0.9663
# Epoch 8/10
# 312/312 [==============================] - 36s 114ms/step - loss: 0.0534 - accuracy: 0.9807 - val_loss: 0.0894 - val_accuracy: 0.9646
# Epoch 9/10
# 312/312 [==============================] - 36s 114ms/step - loss: 0.0485 - accuracy: 0.9828 - val_loss: 0.0901 - val_accuracy: 0.9663
# Epoch 10/10
# 312/312 [==============================] - 36s 114ms/step - loss: 0.0448 - accuracy: 0.9839 - val_loss: 0.0899 - val_accuracy: 0.9634

# %%
scores = model.evaluate_generator(test_generator, nb_test_samples // batch_size)
print("Accuracy on test data: %.2f%%" % (scores[1]*100))
# Out:
# C:\Users\prazd\AppData\Local\Temp\ipykernel_3396\477001200.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   scores = model.evaluate_generator(test_generator, nb_test_samples // batch_size)
# Accuracy on test data: 96.23%

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss with InceptionV3')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy with InceptionV3')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ### Part 3

# %%
from keras.models import *
from keras.layers import *
from keras.applications import *
from keras.preprocessing.image import *
from keras.optimizers import Adam, RMSprop

import h5py

import numpy as np
from sklearn.metrics import accuracy_score

# %%
# Initialize the folders with train, test and validation datasets (in "/My Drive/..." or from your local repository where you have downloaded data):

import os
train = os.path.join('data', 'сats_and_dogs', 'train')
val =   os.path.join('data', 'сats_and_dogs', 'val')
test =  os.path.join('data', 'сats_and_dogs', 'test')

# minibatch size
batch_size = 64

# %%
def write_gap(MODEL, image_size, lambda_func=None):
    width = image_size[0]
    height = image_size[1]
    input_tensor = Input((height, width, 3))
    x = input_tensor
    if lambda_func:
        x = Lambda(lambda_func)(x)
    
    base_model = MODEL(input_tensor=x, weights='imagenet', include_top=False)
    model = Model(base_model.input, GlobalAveragePooling2D()(base_model.output))

    datagen = ImageDataGenerator()
    train_generator = datagen.flow_from_directory(
        train,
        target_size=(width, height),
        batch_size=batch_size,
        class_mode='binary',
        shuffle=False
    )

    val_generator = datagen.flow_from_directory(
        val,
        target_size=(width, height),
        batch_size=batch_size,
        class_mode='binary',
        shuffle=False
    )

    test_generator = datagen.flow_from_directory(
        test,
        target_size=(width, height),
        batch_size=batch_size,
        class_mode='binary',
        shuffle=False
    )

    train_data = model.predict_generator(train_generator)
    val_data = model.predict_generator(val_generator)
    test_data = model.predict_generator(test_generator)
    with h5py.File(f"gap_{MODEL.__name__}.h5", 'w') as h:
        h.create_dataset("train", data=train_data)
        h.create_dataset("val", data=val_data)
        h.create_dataset("test", data=test_data)
        h.create_dataset("train_labels", data=train_generator.classes)
        h.create_dataset("val_labels", data=val_generator.classes)
        h.create_dataset("test_labels", data=test_generator.classes)

# %%
write_gap(EfficientNetV2B3, (299, 299), efficientnet_v2.preprocess_input)
# Out:
# Found 20000 images belonging to 2 classes.
# Found 2490 images belonging to 2 classes.
# Found 2500 images belonging to 2 classes.
# C:\Users\prazd\AppData\Local\Temp\ipykernel_19940\3901065670.py:37: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   train_data = model.predict_generator(train_generator)
# C:\Users\prazd\AppData\Local\Temp\ipykernel_19940\3901065670.py:38: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   val_data = model.predict_generator(val_generator)
# C:\Users\prazd\AppData\Local\Temp\ipykernel_19940\3901065670.py:39: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   test_data = model.predict_generator(test_generator)

# %%
write_gap(EfficientNetV2S, (299, 299), efficientnet_v2.preprocess_input)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-s_notop.h5
# 82420632/82420632 [==============================] - 8s 0us/step
# Found 20000 images belonging to 2 classes.
# Found 2490 images belonging to 2 classes.
# Found 2500 images belonging to 2 classes.
# C:\Users\prazd\AppData\Local\Temp\ipykernel_19940\3901065670.py:37: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   train_data = model.predict_generator(train_generator)
# C:\Users\prazd\AppData\Local\Temp\ipykernel_19940\3901065670.py:38: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   val_data = model.predict_generator(val_generator)
# C:\Users\prazd\AppData\Local\Temp\ipykernel_19940\3901065670.py:39: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   test_data = model.predict_generator(test_generator)

# %%
write_gap(EfficientNetV2B2, (299, 299), efficientnet_v2.preprocess_input)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b2_notop.h5
# 35839040/35839040 [==============================] - 4s 0us/step
# Found 20000 images belonging to 2 classes.
# Found 2490 images belonging to 2 classes.
# Found 2500 images belonging to 2 classes.
# C:\Users\prazd\AppData\Local\Temp\ipykernel_18840\3901065670.py:37: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   train_data = model.predict_generator(train_generator)
# C:\Users\prazd\AppData\Local\Temp\ipykernel_18840\3901065670.py:38: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   val_data = model.predict_generator(val_generator)
# C:\Users\prazd\AppData\Local\Temp\ipykernel_18840\3901065670.py:39: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   test_data = model.predict_generator(test_generator)

# %%
write_gap(EfficientNetV2M, (299, 299), efficientnet_v2.preprocess_input)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214201816/214201816 [==============================] - 19s 0us/step
# Found 20000 images belonging to 2 classes.
# Found 2490 images belonging to 2 classes.
# Found 2500 images belonging to 2 classes.
# C:\Users\prazd\AppData\Local\Temp\ipykernel_18840\3901065670.py:37: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   train_data = model.predict_generator(train_generator)
# C:\Users\prazd\AppData\Local\Temp\ipykernel_18840\3901065670.py:38: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   val_data = model.predict_generator(val_generator)
# C:\Users\prazd\AppData\Local\Temp\ipykernel_18840\3901065670.py:39: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   test_data = model.predict_generator(test_generator)

# %%
write_gap(EfficientNetB7, (150, 150), efficientnet.preprocess_input)
# Out:
# Found 20000 images belonging to 2 classes.
# Found 2490 images belonging to 2 classes.
# Found 2500 images belonging to 2 classes.
# C:\Users\prazd\AppData\Local\Temp\ipykernel_28388\3901065670.py:37: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   train_data = model.predict_generator(train_generator)
# C:\Users\prazd\AppData\Local\Temp\ipykernel_28388\3901065670.py:38: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   val_data = model.predict_generator(val_generator)
# C:\Users\prazd\AppData\Local\Temp\ipykernel_28388\3901065670.py:39: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   test_data = model.predict_generator(test_generator)

# %%
import h5py
import numpy as np
from sklearn.utils import shuffle
np.random.seed(2017)

X_train = []
X_val = []
X_test = []

models = [
    "gap_EfficientNetB3.h5",
    "gap_EfficientNetB7.h5",
    "gap_EfficientNetV2S.h5",
    "gap_EfficientNetV2M.h5",
    "gap_EfficientNetV2B2.h5",
    "gap_EfficientNetV2B3.h5"
]

for filename in models:
    with h5py.File(filename, 'r') as h:
        X_train.append(np.array(h['train']))
        X_val.append(np.array(h['val']))
        X_test.append(np.array(h['test']))
        y_train = np.array(h['train_labels'])
        y_val = np.array(h['val_labels'])
        y_test = np.array(h['test_labels'])

X_train = np.concatenate(X_train, axis=1)
X_val = np.concatenate(X_val, axis=1)
X_test = np.concatenate(X_test, axis=1)

X_train, y_train = shuffle(X_train, y_train)

# %%
input_tensor = Input(X_train.shape[1:])
x = input_tensor
x = Dropout(0.5)(x)
x = Dense(64, activation='relu')(x)
x = Dropout(0.25)(x)
x = Dense(1, activation='sigmoid')(x)
model = Model(input_tensor, x)


model.compile(optimizer='rmsprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train, batch_size=64, epochs=10, validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 313/313 [==============================] - 1s 4ms/step - loss: 9.4982e-04 - accuracy: 0.9997 - val_loss: 0.0758 - val_accuracy: 0.9940
# Epoch 2/10
# 313/313 [==============================] - 1s 4ms/step - loss: 5.2847e-04 - accuracy: 0.9999 - val_loss: 0.0781 - val_accuracy: 0.9944
# Epoch 3/10
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.0806 - val_accuracy: 0.9944
# Epoch 4/10
# 313/313 [==============================] - 1s 4ms/step - loss: 1.1907e-04 - accuracy: 1.0000 - val_loss: 0.0778 - val_accuracy: 0.9944
# Epoch 5/10
# 313/313 [==============================] - 1s 4ms/step - loss: 2.0623e-04 - accuracy: 1.0000 - val_loss: 0.0874 - val_accuracy: 0.9940
# Epoch 6/10
# 313/313 [==============================] - 1s 4ms/step - loss: 5.8601e-04 - accuracy: 0.9999 - val_loss: 0.0848 - val_accuracy: 0.9948
# Epoch 7/10
# 313/313 [==============================] - 1s 4ms/step - loss: 8.3120e-04 - accuracy: 0.9999 - val_loss: 0.0824 - val_accuracy: 0.9948
# Epoch 8/10
# 313/313 [==============================] - 1s 4ms/step - loss: 1.5719e-04 - accuracy: 0.9999 - val_loss: 0.0786 - val_accuracy: 0.9936
# Epoch 9/10
# 313/313 [==============================] - 1s 4ms/step - loss: 4.5955e-04 - accuracy: 0.9999 - val_loss: 0.0876 - val_accuracy: 0.9944
# Epoch 10/10
# 313/313 [==============================] - 1s 4ms/step - loss: 1.6853e-04 - accuracy: 1.0000 - val_loss: 0.0804 - val_accuracy: 0.9952

# %%
model.evaluate(X_test, y_test)
# Out:
# 79/79 [==============================] - 0s 3ms/step - loss: 0.0804 - accuracy: 0.9952
# [0.08039796352386475, 0.9952000379562378]
